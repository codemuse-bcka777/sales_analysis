# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 973.4 kB/s  0:00:02
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 26.0.1
#     Uninstalling pip-26.0.1:
#       Successfully uninstalled pip-26.0.1
# ...

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("SuperMarket Analysis.csv")

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# Year                       0
# Month                      0
# Month Name                 0
# Quarter                    0
# Year_month                 0
# Day_of_week                0
# dtype: int64

# %%
#top 10 products which provide the most revenue
top_products= (df.groupby("Product line")["Sales"].sum().sort_values(ascending=False).head(10))
print(top_products)
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Sales, dtype: float64

# %%
# Which regions perform best and worst?
region_perf = (df.groupby('City')
                 .agg(total_sales=('Sales','sum'), #sum of sales
                      total_orders=('Invoice ID','count'), #number of sales
                      avg_order_value=('Sales','mean')) #average sales amount
                 .sort_values('total_sales', ascending=False))
print(region_perf)
# Out:
#            total_sales  total_orders  avg_order_value
# City
# Naypyitaw  110568.7065           328       337.099715
# Yangon     106200.3705           340       312.354031
# Mandalay   106197.6720           332       319.872506
